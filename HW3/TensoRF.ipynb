# %%
# Mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !rm -rf TensoRF
# !git clone https://github.com/astonastonaston/TensoRF.git
# Out:
# Cloning into 'TensoRF'...
# remote: Enumerating objects: 666, done.
# remote: Counting objects: 100% (624/624), done.
# remote: Compressing objects: 100% (560/560), done.
# remote: Total 666 (delta 84), reused 573 (delta 55), pack-reused 42
# Receiving objects: 100% (666/666), 296.04 MiB | 15.79 MiB/s, done.
# Resolving deltas: 100% (97/97), done.

# %%
# !pip install torch torchvision && pip install tqdm scikit-image opencv-python configargparse lpips imageio-ffmpeg kornia lpips tensorboard plyfile
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 2.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 705.7/705.7 kB 21.3 MB/s eta 0:00:00
# ...

# %%
# load my own dataset
# !mkdir TensoRF/data
# !mkdir TensoRF/data/nerf_synthetic
# !cp -r /content/drive/MyDrive/bottles/bottles /content/TensoRF/data/nerf_synthetic

# %%
# !cd TensoRF && python train.py --config configs/bottles.txt --dataset_name tankstemple
# Out:
# 2023-12-10 21:13:30.205253: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-10 21:13:30.205296: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-10 21:13:30.205327: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-10 21:13:31.251218: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %%
# !echo "data/*" > TensoRF/.gitignore
# !cat TensoRF/.gitignore
# !cd TensoRF && git remote rm origin && git remote add origin https://astonastonaston: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@github.com/astonastonaston/TensoRF.git &&\
# git push -u origin main
# git add . && git commit -m "update to make runnable" && \
# git push -u origin main

# %%
# !cd TensoRF && python train.py --config configs/bottles.txt --dataset_name tankstemple
# Out:
# 2023-12-10 21:13:30.205253: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-10 21:13:30.205296: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-10 21:13:30.205327: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-10 21:13:31.251218: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %%
# !cp -r TensoRF/log /content/drive/MyDrive/HW3_res/log_bottles
